# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
from tensorflow.keras.optimizers import Adam

# %%
epochs = 1000
learning_rate = .04

# %%
a = tf.Variable(np.random.randn())
b = tf.Variable(np.random.randn())
c = tf.Variable(np.random.randn())
d = tf.Variable(np.random.randn())

# %%
X = np.random.randn(50)
Y = X**3 + X**2 + X*np.random.randn(50)

# %%
line_x = np.arange(min(X), max(X), .001)
line_y = a*line_x**3 + b*line_x**2 + c*line_x + d

x_ = np.arange(-4., 4., .001)
y_  = a*x_**3 + b*x_**2 + c*x_ + d
plt.scatter(X,Y, label='X data')
plt.plot(x_, y_, 'g--', label='origin line')
plt.plot(line_x, line_y, 'r--', label='before train')
plt.xlim(-4., 4.)
plt.legend()
plt.grid()
plt.show()

# %%
def compute_loss():
  pred_y = a*(np.array(X)**3) + b*(np.array(X)**2) + c*np.array(X)**1 + d
  loss = tf.reduce_mean((Y-pred_y)**2)
  return loss

# %%
optimizer = Adam(learning_rate=learning_rate)

# %%
for epoch in range(1, epochs+1, 1):
  optimizer.minimize(compute_loss, var_list=[a,b,c,d])

  if epoch % 100 == 0:
    print('epoch: {:4d}\ta: {:.4f}\tb: {:.4f}\tc: {:.4f}\td: {:.4f}'.format(epoch, a.numpy(), b.numpy(), c.numpy(), d.numpy()))
# Out:
# epoch:  100	a: 0.8438	b: 1.0567	c: 0.9304	d: 0.1735
# epoch:  200	a: 0.9109	b: 1.1400	c: 0.5722	d: -0.0895
# epoch:  300	a: 0.9645	b: 1.1246	c: 0.2876	d: -0.0937
# epoch:  400	a: 1.0002	b: 1.1099	c: 0.1003	d: -0.0853
# epoch:  500	a: 1.0201	b: 1.1017	c: -0.0044	d: -0.0805
# epoch:  600	a: 1.0297	b: 1.0977	c: -0.0549	d: -0.0782
# epoch:  700	a: 1.0337	b: 1.0961	c: -0.0762	d: -0.0772
# epoch:  800	a: 1.0352	b: 1.0955	c: -0.0840	d: -0.0769
# epoch:  900	a: 1.0357	b: 1.0953	c: -0.0865	d: -0.0767
# epoch: 1000	a: 1.0358	b: 1.0952	c: -0.0872	d: -0.0767

# %%
line_x = np.arange(min(X), max(X), .001)
line_y = a*line_x**3 + b*line_x**2 + c*line_x + d

plt.scatter(X,Y, label='X data')
plt.plot(x_, y_, 'g--', label='origin line')
plt.plot(line_x, line_y, 'r--', label='after train')
plt.xlim(-4., 4.)
plt.legend()
plt.grid()
plt.show()
